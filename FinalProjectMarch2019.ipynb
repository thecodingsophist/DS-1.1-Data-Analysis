# %% [markdown]
# ## Final Project for D.S 1.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "TimeUse.csv"

df = pd.read_csv(PATH)

# %%
df
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 0     Males                                    Belgium  24:00         10:45
# 1     Males                                   Bulgaria  24:00         11:54
# 2     Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3     Males                                    Estonia  24:00         10:35
# 4     Males                                      Spain  24:00         11:11
# 5     Males                                     France  24:00         11:44
# 6     Males                                      Italy  24:00         11:16
# 7     Males                                     Latvia  24:00         10:46
# 8     Males                                  Lithuania  24:00         10:53
# 9     Males                                     Poland  24:00         10:44
# 10    Males                                   Slovenia  24:00         10:31
# ...

# %%
df_Male = df[(df['SEX'] == 'Males')]

# %%
df_Male.sort_values(['Personal care'], ascending=False)
# Out:
#       SEX                                  GEO/ACL00  Total Personal care  \
# 1   Males                                   Bulgaria  24:00         11:54
# 5   Males                                     France  24:00         11:44
# 6   Males                                      Italy  24:00         11:16
# 4   Males                                      Spain  24:00         11:11
# 8   Males                                  Lithuania  24:00         10:53
# 7   Males                                     Latvia  24:00         10:46
# 0   Males                                    Belgium  24:00         10:45
# 9   Males                                     Poland  24:00         10:44
# 2   Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3   Males                                    Estonia  24:00         10:35
# 10  Males                                   Slovenia  24:00         10:31
# 11  Males                                    Finland  24:00         10:23
# ...

# %% [markdown]
# ## Males who spent the most time in personal care:
# - Bulgaria
# - France
# - Italy

# %%
df_Female = df[(df['SEX'] == 'Females')]

# %%
df_Female.sort_values(['Personal care'], ascending=False)
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 19  Females                                     France  24:00         11:53
# 15  Females                                   Bulgaria  24:00         11:38
# 20  Females                                      Italy  24:00         11:12
# 14  Females                                    Belgium  24:00         11:11
# 18  Females                                      Spain  24:00         11:05
# 23  Females                                     Poland  24:00         11:03
# 16  Females  Germany (including  former GDR from 1991)  24:00         10:58
# 22  Females                                  Lithuania  24:00         10:56
# 21  Females                                     Latvia  24:00         10:53
# 26  Females                             United Kingdom  24:00         10:43
# 25  Females                                    Finland  24:00         10:38
# ...

# %% [markdown]
# ## Females who spent the most time in personal care:
# - France
# - Bulgaria
# - Italy

# %%
df_Male.sort_values(['Sleep'], ascending=False)
# Out:
#       SEX                                  GEO/ACL00  Total Personal care  \
# 1   Males                                   Bulgaria  24:00         11:54
# 5   Males                                     France  24:00         11:44
# 4   Males                                      Spain  24:00         11:11
# 7   Males                                     Latvia  24:00         10:46
# 8   Males                                  Lithuania  24:00         10:53
# 3   Males                                    Estonia  24:00         10:35
# 11  Males                                    Finland  24:00         10:23
# 9   Males                                     Poland  24:00         10:44
# 10  Males                                   Slovenia  24:00         10:31
# 12  Males                             United Kingdom  24:00         10:22
# 6   Males                                      Italy  24:00         11:16
# 0   Males                                    Belgium  24:00         10:45
# ...

# %% [markdown]
# ## Males who spent the most time in sleep
# - Bulgaria
# - France
# - Spain

# %%
df_Female.sort_values(['Sleep'], ascending=False)
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 15  Females                                   Bulgaria  24:00         11:38
# 19  Females                                     France  24:00         11:53
# 21  Females                                     Latvia  24:00         10:53
# 22  Females                                  Lithuania  24:00         10:56
# 23  Females                                     Poland  24:00         11:03
# 14  Females                                    Belgium  24:00         11:11
# 18  Females                                      Spain  24:00         11:05
# 25  Females                                    Finland  24:00         10:38
# 26  Females                             United Kingdom  24:00         10:43
# 17  Females                                    Estonia  24:00         10:30
# 24  Females                                   Slovenia  24:00         10:32
# ...

# %% [markdown]
# ## Females who spent the most time in sleep:
# - Bulgaria
# - France
# - Latvia

# %%
df_Male.sort_values(['Employment, related activities and travel as part of/during main and second job'], ascending=False)
# Out:
#       SEX                                  GEO/ACL00  Total Personal care  \
# 7   Males                                     Latvia  24:00         10:46
# 8   Males                                  Lithuania  24:00         10:53
# 3   Males                                    Estonia  24:00         10:35
# 4   Males                                      Spain  24:00         11:11
# 6   Males                                      Italy  24:00         11:16
# 12  Males                             United Kingdom  24:00         10:22
# 13  Males                                     Norway  24:00         10:06
# 9   Males                                     Poland  24:00         10:44
# 10  Males                                   Slovenia  24:00         10:31
# 5   Males                                     France  24:00         11:44
# 11  Males                                    Finland  24:00         10:23
# 1   Males                                   Bulgaria  24:00         11:54
# ...

# %% [markdown]
# ## Males who spent the most time at work
# - Latvia
# - Lithuania
# - Estonia

# %%
df_Female.sort_values(['Employment, related activities and travel as part of/during main and second job'], ascending=False)
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 22  Females                                  Lithuania  24:00         10:56
# 21  Females                                     Latvia  24:00         10:53
# 17  Females                                    Estonia  24:00         10:30
# 24  Females                                   Slovenia  24:00         10:32
# 27  Females                                     Norway  24:00         10:27
# 15  Females                                   Bulgaria  24:00         11:38
# 25  Females                                    Finland  24:00         10:38
# 26  Females                             United Kingdom  24:00         10:43
# 19  Females                                     France  24:00         11:53
# 23  Females                                     Poland  24:00         11:03
# 18  Females                                      Spain  24:00         11:05
# ...

# %% [markdown]
# ## Females who spent the most time at work:
# - Lithuania
# - Latvia
# - Estonia
